# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_excel('/Users/yongyang/Downloads/0423.xlsx')

# %%
df.fillna(method='ffill',axis=1) # bfill > b- backward
# Out:
#             KHH KHXM            ZJZH ZHMC   BZ ZHGLJG ZHLB  YWFW  SRYE  ZHYE  \
# 0     100511087  乐小城  00010051108701  乐小城  RMB      1  1.0  16.0  0.01  0.01
# 1     100621073  汪长根  00010062107301  汪长根  RMB      1  1.0  16.0  0.01  0.01
# 2     100002533   林洵  00010000253301   林洵  RMB      1  1.0  16.0  0.05  0.05
# 3     100333938  林秋霞  00010033393801  林秋霞  RMB      1  1.0  16.0  0.01  0.01
# 4     100505105  吴家允  00010050510501  吴家允  RMB      1  1.0  16.0  0.01  0.01
# ...         ...  ...             ...  ...  ...    ...  ...   ...   ...   ...
# 3941  100363906  庞晓冬  00010036390601  庞晓冬  RMB      1  1.0  16.0  0.01  0.01
# 3942  100408337  谭建英  00010040833701  谭建英  RMB      1  1.0  16.0  0.03  0.03
# 3943  100586743  邹福兰  00010058674301  邹福兰  RMB      1  1.0  16.0  0.02  0.02
# 3944  100407675  赵海霞  00010040767501  赵海霞  RMB      1  1.0  16.0  0.01  0.01
# 3945  100383136  李明姣  00010038313601  李明姣  RMB      1  1.0  16.0  0.01  0.01
#
# ...

# %%
df[df['EMAIL']==""].index
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 3941   NaN
# 3942   NaN
# 3943   NaN
# 3944   NaN
# 3945   NaN
# Name: EMAIL, Length: 3946, dtype: float64

# %%
df.loc[df[df['EMAIL']==""].index,'EMAIL']='a@text.com' # 通过索引去填充

# %%
# 填充缺失值
# 确定你要填充的内容 》》》 定位》》》 赋值


# 填充多个值
df.fillna({'EMAIL':'a@ttest.com','MOBILE':'123232132'})
# Out:
#             KHH KHXM            ZJZH ZHMC   BZ  ZHGLJG  ZHLB  YWFW  SRYE  \
# 0     100511087  乐小城  00010051108701  乐小城  RMB       1   1.0  16.0  0.01
# 1     100621073  汪长根  00010062107301  汪长根  RMB       1   1.0  16.0  0.01
# 2     100002533   林洵  00010000253301   林洵  RMB       1   1.0  16.0  0.05
# 3     100333938  林秋霞  00010033393801  林秋霞  RMB       1   1.0  16.0  0.01
# 4     100505105  吴家允  00010050510501  吴家允  RMB       1   1.0  16.0  0.01
# ...         ...  ...             ...  ...  ...     ...   ...   ...   ...
# 3941  100363906  庞晓冬  00010036390601  庞晓冬  RMB       1   1.0  16.0  0.01
# 3942  100408337  谭建英  00010040833701  谭建英  RMB       1   1.0  16.0  0.03
# 3943  100586743  邹福兰  00010058674301  邹福兰  RMB       1   1.0  16.0  0.02
# 3944  100407675  赵海霞  00010040767501  赵海霞  RMB       1   1.0  16.0  0.01
# 3945  100383136  李明姣  00010038313601  李明姣  RMB       1   1.0  16.0  0.01
#
#       ZHYE  ...  KHKH           FXCJYMM  KHJF  JFQSRQ  EMAIL  MOBILE   XB  \
# ...

# %%
df['ZHYE'].mean() # 计算均值，默认去掉缺失值
# Out:
# 2.8966953877344492

# %%
df.loc[0,'KHKH']
# Out:
# nan

# %%
df.loc[0,'KHKH'] +1
# Out:
# nan

# %%
# 替换值 inplace
df.replace('乐小城','乐大城',inplace=True) # 默认不对元对象修改

# %%
df
# Out:
#             KHH KHXM            ZJZH ZHMC   BZ  ZHGLJG  ZHLB  YWFW  SRYE  \
# 0     100511087  乐大城  00010051108701  乐大城  RMB       1   1.0  16.0  0.01
# 1     100621073  汪长根  00010062107301  汪长根  RMB       1   1.0  16.0  0.01
# 2     100002533   林洵  00010000253301   林洵  RMB       1   1.0  16.0  0.05
# 3     100333938  林秋霞  00010033393801  林秋霞  RMB       1   1.0  16.0  0.01
# 4     100505105  吴家允  00010050510501  吴家允  RMB       1   1.0  16.0  0.01
# ...         ...  ...             ...  ...  ...     ...   ...   ...   ...
# 3941  100363906  庞晓冬  00010036390601  庞晓冬  RMB       1   1.0  16.0  0.01
# 3942  100408337  谭建英  00010040833701  谭建英  RMB       1   1.0  16.0  0.03
# 3943  100586743  邹福兰  00010058674301  邹福兰  RMB       1   1.0  16.0  0.02
# 3944  100407675  赵海霞  00010040767501  赵海霞  RMB       1   1.0  16.0  0.01
# 3945  100383136  李明姣  00010038313601  李明姣  RMB       1   1.0  16.0  0.01
#
#       ZHYE  ...  KHKH           FXCJYMM  KHJF  JFQSRQ  EMAIL  MOBILE   XB  \
# ...

# %%
# 多对一替换
df.replace(['乐大城','汪长根'],'小明',inplace=True)

# %%
df
# Out:
#             KHH KHXM            ZJZH ZHMC   BZ  ZHGLJG  ZHLB  YWFW  SRYE  \
# 0     100511087   小明  00010051108701   小明  RMB       1   1.0  16.0  0.01
# 1     100621073   小明  00010062107301   小明  RMB       1   1.0  16.0  0.01
# 2     100002533   林洵  00010000253301   林洵  RMB       1   1.0  16.0  0.05
# 3     100333938  林秋霞  00010033393801  林秋霞  RMB       1   1.0  16.0  0.01
# 4     100505105  吴家允  00010050510501  吴家允  RMB       1   1.0  16.0  0.01
# ...         ...  ...             ...  ...  ...     ...   ...   ...   ...
# 3941  100363906  庞晓冬  00010036390601  庞晓冬  RMB       1   1.0  16.0  0.01
# 3942  100408337  谭建英  00010040833701  谭建英  RMB       1   1.0  16.0  0.03
# 3943  100586743  邹福兰  00010058674301  邹福兰  RMB       1   1.0  16.0  0.02
# 3944  100407675  赵海霞  00010040767501  赵海霞  RMB       1   1.0  16.0  0.01
# 3945  100383136  李明姣  00010038313601  李明姣  RMB       1   1.0  16.0  0.01
#
#       ZHYE  ...  KHKH           FXCJYMM  KHJF  JFQSRQ  EMAIL  MOBILE   XB  \
# ...

# %%
# 多对多替换
df.replace({'小明':'乐大城','00010051108701':'000100AAAA'})
# Out:
#             KHH KHXM            ZJZH ZHMC   BZ  ZHGLJG  ZHLB  YWFW  SRYE  \
# 0     100511087  乐大城      000100AAAA  乐大城  RMB       1   1.0  16.0  0.01
# 1     100621073  乐大城  00010062107301  乐大城  RMB       1   1.0  16.0  0.01
# 2     100002533   林洵  00010000253301   林洵  RMB       1   1.0  16.0  0.05
# 3     100333938  林秋霞  00010033393801  林秋霞  RMB       1   1.0  16.0  0.01
# 4     100505105  吴家允  00010050510501  吴家允  RMB       1   1.0  16.0  0.01
# ...         ...  ...             ...  ...  ...     ...   ...   ...   ...
# 3941  100363906  庞晓冬  00010036390601  庞晓冬  RMB       1   1.0  16.0  0.01
# 3942  100408337  谭建英  00010040833701  谭建英  RMB       1   1.0  16.0  0.03
# 3943  100586743  邹福兰  00010058674301  邹福兰  RMB       1   1.0  16.0  0.02
# 3944  100407675  赵海霞  00010040767501  赵海霞  RMB       1   1.0  16.0  0.01
# 3945  100383136  李明姣  00010038313601  李明姣  RMB       1   1.0  16.0  0.01
#
#       ZHYE  ...  KHKH           FXCJYMM  KHJF  JFQSRQ  EMAIL  MOBILE   XB  \
# ...

# %%
# 判断重复值 duplicated()
df.duplicated()  # 默认在行上判断，全部相同才是True
# 删除重复值 drop_duplicates()
df.drop_duplicates('ZHMC') # 删除相同行，后面的行，keep=first、默认保留第一个 keep=false 相同的全部删除，可以指定列
# Out:
#             KHH KHXM            ZJZH ZHMC   BZ  ZHGLJG  ZHLB  YWFW  SRYE  \
# 0     100511087   小明  00010051108701   小明  RMB       1   1.0  16.0  0.01
# 2     100002533   林洵  00010000253301   林洵  RMB       1   1.0  16.0  0.05
# 3     100333938  林秋霞  00010033393801  林秋霞  RMB       1   1.0  16.0  0.01
# 4     100505105  吴家允  00010050510501  吴家允  RMB       1   1.0  16.0  0.01
# 5     100589772  柯亚彩  00010058977201  柯亚彩  RMB       1   1.0  16.0  0.02
# ...         ...  ...             ...  ...  ...     ...   ...   ...   ...
# 3941  100363906  庞晓冬  00010036390601  庞晓冬  RMB       1   1.0  16.0  0.01
# 3942  100408337  谭建英  00010040833701  谭建英  RMB       1   1.0  16.0  0.03
# 3943  100586743  邹福兰  00010058674301  邹福兰  RMB       1   1.0  16.0  0.02
# 3944  100407675  赵海霞  00010040767501  赵海霞  RMB       1   1.0  16.0  0.01
# 3945  100383136  李明姣  00010038313601  李明姣  RMB       1   1.0  16.0  0.01
#
#       ZHYE  ...  KHKH           FXCJYMM  KHJF  JFQSRQ  EMAIL  MOBILE   XB  \
# ...

# %%
df.drop_duplicates(['EMAIL','KHKH'],ignore_index=True) # 忽略原始index
# Out:
#          KHH                KHXM            ZJZH ZHMC   BZ  ZHGLJG  ZHLB  \
# 0  100511087                  小明  00010051108701   小明  RMB       1  1.00
# 1  100601116  钱储,00010060111601"         钱储,RMB"    1    1      16  0.01
#
#     YWFW  SRYE  ZHYE  ...  KHKH           FXCJYMM  KHJF  JFQSRQ  EMAIL  \
# 0  16.00  0.01  0.01  ...   NaN  xszdynwlwdxoyhse     0       0    NaN
# 1   0.01  0.00  0.00  ...   NaN               NaN     0       0    0.0
#
#        MOBILE   XB  ZJDLRQ  MMTBBZ      MMBDRQ
# 0         NaN  0.0     0.0     0.0  20160125.0
# 1  20161223.0  NaN     NaN     NaN         NaN
#
# [2 rows x 73 columns]

# %%
df['ZHMC'].unique() # 唯一值
# Out:
# array(['小明', '林洵', '林秋霞', ..., '邹福兰', '赵海霞', '李明姣'], dtype=object)

# %%
df['ZHMC'].nunique() # 唯一值的个数
# Out:
# 3849

# %%
df.sort_values(by='YWFW',ascending=False) # 降序排序，默认升序
# Out:
#             KHH                 KHXM            ZJZH ZHMC   BZ  ZHGLJG  ZHLB  \
# 0     100511087                   小明  00010051108701   小明  RMB       1  1.00
# 2620  100587145                  曹光银  00010058714501  曹光银  RMB       1  1.00
# 2622  100605017                   秦俊  00010060501701   秦俊  RMB       1  1.00
# 2623  100577471                  赵梅仙  00010057747101  赵梅仙  RMB       1  1.00
# 2624  100247085                  王明坤  00010024708501  王明坤  RMB       1  1.00
# ...         ...                  ...             ...  ...  ...     ...   ...
# 3945  100383136                  李明姣  00010038313601  李明姣  RMB       1  1.00
# 3372  100616210   刘闸,00010061621001"         刘闸,RMB"    1    1      16  0.02
# 1670  100357241  陈扪尧,00010035724101"        陈扪尧,RMB"    1    1      16  0.01
# 2319  100572152  阮松尧,00010057215201"        阮松尧,RMB"    1    1      16  0.01
# 1667  100601116   钱储,00010060111601"         钱储,RMB"    1    1      16  0.01
#
# ...

# %%
df.sort_index(ascending=False)
# Out:
#             KHH KHXM            ZJZH ZHMC   BZ  ZHGLJG  ZHLB  YWFW  SRYE  \
# 3945  100383136  李明姣  00010038313601  李明姣  RMB       1   1.0  16.0  0.01
# 3944  100407675  赵海霞  00010040767501  赵海霞  RMB       1   1.0  16.0  0.01
# 3943  100586743  邹福兰  00010058674301  邹福兰  RMB       1   1.0  16.0  0.02
# 3942  100408337  谭建英  00010040833701  谭建英  RMB       1   1.0  16.0  0.03
# 3941  100363906  庞晓冬  00010036390601  庞晓冬  RMB       1   1.0  16.0  0.01
# ...         ...  ...             ...  ...  ...     ...   ...   ...   ...
# 4     100505105  吴家允  00010050510501  吴家允  RMB       1   1.0  16.0  0.01
# 3     100333938  林秋霞  00010033393801  林秋霞  RMB       1   1.0  16.0  0.01
# 2     100002533   林洵  00010000253301   林洵  RMB       1   1.0  16.0  0.05
# 1     100621073   小明  00010062107301   小明  RMB       1   1.0  16.0  0.01
# 0     100511087   小明  00010051108701   小明  RMB       1   1.0  16.0  0.01
#
#       ZHYE  ...  KHKH           FXCJYMM  KHJF  JFQSRQ  EMAIL  MOBILE   XB  \
# ...

# %%
df.sort_index? # 查看函数信息

# %%
# 数据类型转换
#pandase dtype | python type
dd= pd.DataFrame({'pandase dtype':['object','int64','float64','bool',"datetime64",'timedelta[ns]','category'],
                 'python type':['str or mixed','int','float','bool','NA','NA','NA']})
dd
# Out:
#    pandase dtype   python type
# 0         object  str or mixed
# 1          int64           int
# 2        float64         float
# 3           bool          bool
# 4     datetime64            NA
# 5  timedelta[ns]            NA
# 6       category            NA

# %%
df = pd.DataFrame({'a':[1,2,3],'b':[0.55,0.66,1.55],'c':['Jack','Tony','Posi']})
df
# Out:
#    a     b     c
# 0  1  0.55  Jack
# 1  2  0.66  Tony
# 2  3  1.55  Posi

# %%
df.dtypes
# Out:
# a      int64
# b    float64
# c     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       3 non-null      int64
#  1   b       3 non-null      float64
#  2   c       3 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 200.0+ bytes

# %%
# 更改数值类型 astype()
df['b'].astype(int)
# Out:
# 0    0
# 1    0
# 2    1
# Name: b, dtype: int64

# %%
df.dtypes
# Out:
# a      int64
# b    float64
# c     object
# dtype: object

# %%
df['b']=df['b'].astype(int)#向下取整
df
# Out:
#    a  b     c
# 0  1  0  Jack
# 1  2  0  Tony
# 2  3  1  Posi

# %%
df.dtypes
# Out:
# a     int64
# b     int64
# c    object
# dtype: object

# %%
# to_numeric 转化成数值类型（int，float）
df = pd.DataFrame({'a':[1,2,3,7],'b':[0.55,0.66,1.55,'miss'],'c':['Jack','Tony','Posi','James']})
df
# Out:
#    a     b      c
# 0  1  0.55   Jack
# 1  2  0.66   Tony
# 2  3  1.55   Posi
# 3  7  miss  James

# %%
df['b']=pd.to_numeric(df['b'],errors='coerce') # 不能解析的置为nan，

# %%
df
# Out:
#    a     b      c
# 0  1  0.55   Jack
# 1  2  0.66   Tony
# 2  3  1.55   Posi
# 3  7   NaN  James

# %%
# 时间类型 to_datetime
df = pd.read_excel('/Users/yongyang/Downloads/0423.xlsx')
df
# Out:
#             KHH KHXM            ZJZH ZHMC   BZ  ZHGLJG  ZHLB  YWFW  SRYE  \
# 0     100511087  乐小城  00010051108701  乐小城  RMB       1   1.0  16.0  0.01
# 1     100621073  汪长根  00010062107301  汪长根  RMB       1   1.0  16.0  0.01
# 2     100002533   林洵  00010000253301   林洵  RMB       1   1.0  16.0  0.05
# 3     100333938  林秋霞  00010033393801  林秋霞  RMB       1   1.0  16.0  0.01
# 4     100505105  吴家允  00010050510501  吴家允  RMB       1   1.0  16.0  0.01
# ...         ...  ...             ...  ...  ...     ...   ...   ...   ...
# 3941  100363906  庞晓冬  00010036390601  庞晓冬  RMB       1   1.0  16.0  0.01
# 3942  100408337  谭建英  00010040833701  谭建英  RMB       1   1.0  16.0  0.03
# 3943  100586743  邹福兰  00010058674301  邹福兰  RMB       1   1.0  16.0  0.02
# 3944  100407675  赵海霞  00010040767501  赵海霞  RMB       1   1.0  16.0  0.01
# 3945  100383136  李明姣  00010038313601  李明姣  RMB       1   1.0  16.0  0.01
#
#       ZHYE  ...  KHKH           FXCJYMM  KHJF  JFQSRQ  EMAIL  MOBILE   XB  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3946 entries, 0 to 3945
# Data columns (total 73 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   KHH       3946 non-null   int64
#  1   KHXM      3946 non-null   object
#  2   ZJZH      3946 non-null   object
#  3   ZHMC      3946 non-null   object
#  4   BZ        3946 non-null   object
#  5   ZHGLJG    3946 non-null   int64
#  6   ZHLB      3946 non-null   float64
#  7   YWFW      3946 non-null   float64
#  8   SRYE      3946 non-null   float64
#  9   ZHYE      3946 non-null   float64
#  10  DJJE      3946 non-null   int64
#  11  LXJS      3946 non-null   float64
#  12  DZLX      3946 non-null   int64
#  13  YJLX      3946 non-null   float64
#  14  TZJS      3946 non-null   float64
#  15  ZHZT      3946 non-null   int64
#  16  ZZHBZ     3946 non-null   int64
#  17  ZHSX      3946 non-null   int64
#  18  KHRQ      3946 non-null   int64
#  19  XHRQ      3946 non-null   int64
# ...

# %%
df['MMBDRQ']=pd.to_datetime(df['MMBDRQ'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3946 entries, 0 to 3945
# Data columns (total 73 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   KHH       3946 non-null   int64
#  1   KHXM      3946 non-null   object
#  2   ZJZH      3946 non-null   object
#  3   ZHMC      3946 non-null   object
#  4   BZ        3946 non-null   object
#  5   ZHGLJG    3946 non-null   int64
#  6   ZHLB      3946 non-null   float64
#  7   YWFW      3946 non-null   float64
#  8   SRYE      3946 non-null   float64
#  9   ZHYE      3946 non-null   float64
#  10  DJJE      3946 non-null   int64
#  11  LXJS      3946 non-null   float64
#  12  DZLX      3946 non-null   int64
#  13  YJLX      3946 non-null   float64
#  14  TZJS      3946 non-null   float64
#  15  ZHZT      3946 non-null   int64
#  16  ZZHBZ     3946 non-null   int64
#  17  ZHSX      3946 non-null   int64
#  18  KHRQ      3946 non-null   int64
#  19  XHRQ      3946 non-null   int64
# ...

# %%
df.set_index('MMBDRQ',inplace=True)

# %%
df
# Out:
#                                      KHH KHXM            ZJZH ZHMC   BZ  \
# MMBDRQ
# 1970-01-01 00:00:00.020160125  100511087  乐小城  00010051108701  乐小城  RMB
# 1970-01-01 00:00:00.020170217  100621073  汪长根  00010062107301  汪长根  RMB
# 1970-01-01 00:00:00.020140923  100002533   林洵  00010000253301   林洵  RMB
# 1970-01-01 00:00:00.020150728  100333938  林秋霞  00010033393801  林秋霞  RMB
# 1970-01-01 00:00:00.020160116  100505105  吴家允  00010050510501  吴家允  RMB
# ...                                  ...  ...             ...  ...  ...
# 1970-01-01 00:00:00.020150815  100363906  庞晓冬  00010036390601  庞晓冬  RMB
# 1970-01-01 00:00:00.020150920  100408337  谭建英  00010040833701  谭建英  RMB
# 1970-01-01 00:00:00.020161107  100586743  邹福兰  00010058674301  邹福兰  RMB
# 1970-01-01 00:00:00.020150917  100407675  赵海霞  00010040767501  赵海霞  RMB
# 1970-01-01 00:00:00.020150901  100383136  李明姣  00010038313601  李明姣  RMB
#
#                                ZHGLJG  ZHLB  YWFW  SRYE  ZHYE  ...  GJDM  \
# ...

# %%
from datetime import datetime
df.index < datetime(2017,3,20)
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
# 提取1月份的数据
df[df.index.month==1]
# Out:
#                                      KHH KHXM            ZJZH ZHMC   BZ  \
# MMBDRQ
# 1970-01-01 00:00:00.020160125  100511087  乐小城  00010051108701  乐小城  RMB
# 1970-01-01 00:00:00.020170217  100621073  汪长根  00010062107301  汪长根  RMB
# 1970-01-01 00:00:00.020140923  100002533   林洵  00010000253301   林洵  RMB
# 1970-01-01 00:00:00.020150728  100333938  林秋霞  00010033393801  林秋霞  RMB
# 1970-01-01 00:00:00.020160116  100505105  吴家允  00010050510501  吴家允  RMB
# ...                                  ...  ...             ...  ...  ...
# 1970-01-01 00:00:00.020150815  100363906  庞晓冬  00010036390601  庞晓冬  RMB
# 1970-01-01 00:00:00.020150920  100408337  谭建英  00010040833701  谭建英  RMB
# 1970-01-01 00:00:00.020161107  100586743  邹福兰  00010058674301  邹福兰  RMB
# 1970-01-01 00:00:00.020150917  100407675  赵海霞  00010040767501  赵海霞  RMB
# 1970-01-01 00:00:00.020150901  100383136  李明姣  00010038313601  李明姣  RMB
#
#                                ZHGLJG  ZHLB  YWFW  SRYE  ZHYE  ...  GJDM  \
# ...
